# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
train=pd.read_csv("titanic_train.csv")

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
sns.heatmap(train.isnull())
# Out:
# <AxesSubplot:>

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
train["Age"].fillna(train["Age"].mean(),inplace=True)

# %%
sns.heatmap(train.isnull())
# Out:
# <AxesSubplot:>

# %%
train.drop("Cabin",axis=1,inplace=True)

# %%
sns.heatmap(train.isnull())
# Out:
# <AxesSubplot:>

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked
# 0      0         A/5 21171   7.2500        S
# 1      0          PC 17599  71.2833        C
# 2      0  STON/O2. 3101282   7.9250        S
# 3      0            113803  53.1000        S
# 4      0            373450   8.0500        S

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(4)
# memory usage: 76.7+ KB

# %%
train.dropna(inplace=True)

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked
# 0      0         A/5 21171   7.2500        S
# 1      0          PC 17599  71.2833        C
# 2      0  STON/O2. 3101282   7.9250        S
# 3      0            113803  53.1000        S
# 4      0            373450   8.0500        S

# %%
sex = pd.get_dummies(train['Sex'],drop_first=True)
embark = pd.get_dummies(train['Embarked'],drop_first=True)

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked
# 0      0         A/5 21171   7.2500        S
# 1      0          PC 17599  71.2833        C
# 2      0  STON/O2. 3101282   7.9250        S
# 3      0            113803  53.1000        S
# 4      0            373450   8.0500        S

# %%
sex.head()
# Out:
#    male
# 0     1
# 1     0
# 2     0
# 3     0
# 4     1

# %%
embark.head()
# Out:
#    Q  S
# 0  0  1
# 1  0  0
# 2  0  1
# 3  0  1
# 4  0  1

# %%
train.drop(sex,axis=1,inplace=True)

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      1      0
# 2                             Heikkinen, Miss. Laina  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      1      0
# 4                           Allen, Mr. William Henry  35.0      0      0
#
#              Ticket     Fare Embarked  Q  S  Q  S
# 0         A/5 21171   7.2500        S  0  1  0  1
# 1          PC 17599  71.2833        C  0  0  0  0
# 2  STON/O2. 3101282   7.9250        S  0  1  0  1
# 3            113803  53.1000        S  0  1  0  1
# 4            373450   8.0500        S  0  1  0  1

# %%
train.drop(embark,axis=1,inplace=True)

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      1      0
# 2                             Heikkinen, Miss. Laina  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      1      0
# 4                           Allen, Mr. William Henry  35.0      0      0
#
#              Ticket     Fare Embarked
# 0         A/5 21171   7.2500        S
# 1          PC 17599  71.2833        C
# 2  STON/O2. 3101282   7.9250        S
# 3            113803  53.1000        S
# 4            373450   8.0500        S

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      1      0
# 2                             Heikkinen, Miss. Laina  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      1      0
# 4                           Allen, Mr. William Henry  35.0      0      0
#
#              Ticket     Fare Embarked
# 0         A/5 21171   7.2500        S
# 1          PC 17599  71.2833        C
# 2  STON/O2. 3101282   7.9250        S
# 3            113803  53.1000        S
# 4            373450   8.0500        S

# %%
train=pd.concat([train,sex,embark],axis=1)

# %%
embark.head()
# Out:
#    Q  S
# 0  0  1
# 1  0  0
# 2  0  1
# 3  0  1
# 4  0  1

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          1.0       0.0     3.0
# 1          2.0       1.0     1.0
# 2          3.0       1.0     3.0
# 3          4.0       1.0     1.0
# 4          5.0       0.0     3.0
#
#                                                 Name   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris  22.0    1.0    0.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0    1.0    0.0
# 2                             Heikkinen, Miss. Laina  26.0    0.0    0.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0    1.0    0.0
# 4                           Allen, Mr. William Henry  35.0    0.0    0.0
#
#              Ticket     Fare Embarked  male   Q   S  male  Q  S
# 0         A/5 21171   7.2500        S   NaN NaN NaN     1  0  1
# 1          PC 17599  71.2833        C   NaN NaN NaN     0  0  0
# 2  STON/O2. 3101282   7.9250        S   NaN NaN NaN     0  0  1
# 3            113803  53.1000        S   NaN NaN NaN     0  0  1
# 4            373450   8.0500        S   NaN NaN NaN     1  0  1

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          1.0       0.0     3.0
# 1          2.0       1.0     1.0
# 2          3.0       1.0     3.0
# 3          4.0       1.0     1.0
# 4          5.0       0.0     3.0
#
#                                                 Name   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris  22.0    1.0    0.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0    1.0    0.0
# 2                             Heikkinen, Miss. Laina  26.0    0.0    0.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0    1.0    0.0
# 4                           Allen, Mr. William Henry  35.0    0.0    0.0
#
#              Ticket     Fare Embarked  male   Q   S  male  Q  S
# 0         A/5 21171   7.2500        S   NaN NaN NaN     1  0  1
# 1          PC 17599  71.2833        C   NaN NaN NaN     0  0  0
# 2  STON/O2. 3101282   7.9250        S   NaN NaN NaN     0  0  1
# 3            113803  53.1000        S   NaN NaN NaN     0  0  1
# 4            373450   8.0500        S   NaN NaN NaN     1  0  1

# %%
train.drop(["Embarked","male","Q","S"],axis=1,inplace=True)

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          1.0       0.0     3.0
# 1          2.0       1.0     1.0
# 2          3.0       1.0     3.0
# 3          4.0       1.0     1.0
# 4          5.0       0.0     3.0
#
#                                                 Name   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris  22.0    1.0    0.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0    1.0    0.0
# 2                             Heikkinen, Miss. Laina  26.0    0.0    0.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0    1.0    0.0
# 4                           Allen, Mr. William Henry  35.0    0.0    0.0
#
#              Ticket     Fare
# 0         A/5 21171   7.2500
# 1          PC 17599  71.2833
# 2  STON/O2. 3101282   7.9250
# 3            113803  53.1000
# 4            373450   8.0500

# %%
train=pd.concat([train,embark,sex],axis=1)

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          1.0       0.0     3.0
# 1          2.0       1.0     1.0
# 2          3.0       1.0     3.0
# 3          4.0       1.0     1.0
# 4          5.0       0.0     3.0
#
#                                                 Name   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris  22.0    1.0    0.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0    1.0    0.0
# 2                             Heikkinen, Miss. Laina  26.0    0.0    0.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0    1.0    0.0
# 4                           Allen, Mr. William Henry  35.0    0.0    0.0
#
#              Ticket     Fare  Q  S  male
# 0         A/5 21171   7.2500  0  1     1
# 1          PC 17599  71.2833  0  0     0
# 2  STON/O2. 3101282   7.9250  0  1     0
# 3            113803  53.1000  0  1     0
# 4            373450   8.0500  0  1     1

# %%
train.drop(["Name","Ticket"],axis=1,inplace=True)

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare  Q  S  male
# 0          1.0       0.0     3.0  22.0    1.0    0.0   7.2500  0  1     1
# 1          2.0       1.0     1.0  38.0    1.0    0.0  71.2833  0  0     0
# 2          3.0       1.0     3.0  26.0    0.0    0.0   7.9250  0  1     0
# 3          4.0       1.0     1.0  35.0    1.0    0.0  53.1000  0  1     0
# 4          5.0       0.0     3.0  35.0    0.0    0.0   8.0500  0  1     1

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2667 entries, 0 to 890
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  889 non-null    float64
#  1   Survived     889 non-null    float64
#  2   Pclass       889 non-null    float64
#  3   Age          889 non-null    float64
#  4   SibSp        889 non-null    float64
#  5   Parch        889 non-null    float64
#  6   Fare         889 non-null    float64
#  7   Q            2667 non-null   uint8
#  8   S            2667 non-null   uint8
#  9   male         2667 non-null   uint8
# dtypes: float64(7), uint8(3)
# memory usage: 239.0 KB

# %%
train.drop(["Q","S","male"],axis=1,inplace=True)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2667 entries, 0 to 890
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  889 non-null    float64
#  1   Survived     889 non-null    float64
#  2   Pclass       889 non-null    float64
#  3   Age          889 non-null    float64
#  4   SibSp        889 non-null    float64
#  5   Parch        889 non-null    float64
#  6   Fare         889 non-null    float64
# dtypes: float64(7)
# memory usage: 231.2 KB

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare
# 0          1.0       0.0     3.0  22.0    1.0    0.0   7.2500
# 1          2.0       1.0     1.0  38.0    1.0    0.0  71.2833
# 2          3.0       1.0     3.0  26.0    0.0    0.0   7.9250
# 3          4.0       1.0     1.0  35.0    1.0    0.0  53.1000
# 4          5.0       0.0     3.0  35.0    0.0    0.0   8.0500

# %%
train=pd.concat([train,sex,embark],axis=1)

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare  male  Q  S
# 0          1.0       0.0     3.0  22.0    1.0    0.0   7.2500     1  0  1
# 1          2.0       1.0     1.0  38.0    1.0    0.0  71.2833     0  0  0
# 2          3.0       1.0     3.0  26.0    0.0    0.0   7.9250     0  0  1
# 3          4.0       1.0     1.0  35.0    1.0    0.0  53.1000     0  0  1
# 4          5.0       0.0     3.0  35.0    0.0    0.0   8.0500     1  0  1

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2667 entries, 0 to 890
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  889 non-null    float64
#  1   Survived     889 non-null    float64
#  2   Pclass       889 non-null    float64
#  3   Age          889 non-null    float64
#  4   SibSp        889 non-null    float64
#  5   Parch        889 non-null    float64
#  6   Fare         889 non-null    float64
#  7   male         2667 non-null   uint8
#  8   Q            2667 non-null   uint8
#  9   S            2667 non-null   uint8
# dtypes: float64(7), uint8(3)
# memory usage: 174.5 KB

# %%
sns.heatmap(train.isnull())
# Out:
# <AxesSubplot:>

# %%
train.dropna(inplace=True,axis=0)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 889 entries, 0 to 890
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  889 non-null    float64
#  1   Survived     889 non-null    float64
#  2   Pclass       889 non-null    float64
#  3   Age          889 non-null    float64
#  4   SibSp        889 non-null    float64
#  5   Parch        889 non-null    float64
#  6   Fare         889 non-null    float64
#  7   male         889 non-null    uint8
#  8   Q            889 non-null    uint8
#  9   S            889 non-null    uint8
# dtypes: float64(7), uint8(3)
# memory usage: 58.2 KB

# %%
sns.heatmap(train.isnull())
# Out:
# <AxesSubplot:>

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare  male  Q  S
# 0          1.0       0.0     3.0  22.0    1.0    0.0   7.2500     1  0  1
# 1          2.0       1.0     1.0  38.0    1.0    0.0  71.2833     0  0  0
# 2          3.0       1.0     3.0  26.0    0.0    0.0   7.9250     0  0  1
# 3          4.0       1.0     1.0  35.0    1.0    0.0  53.1000     0  0  1
# 4          5.0       0.0     3.0  35.0    0.0    0.0   8.0500     1  0  1

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 889 entries, 0 to 890
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  889 non-null    float64
#  1   Survived     889 non-null    float64
#  2   Pclass       889 non-null    float64
#  3   Age          889 non-null    float64
#  4   SibSp        889 non-null    float64
#  5   Parch        889 non-null    float64
#  6   Fare         889 non-null    float64
#  7   male         889 non-null    uint8
#  8   Q            889 non-null    uint8
#  9   S            889 non-null    uint8
# dtypes: float64(7), uint8(3)
# memory usage: 58.2 KB

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare  male  Q  S
# 0          1.0       0.0     3.0  22.0    1.0    0.0   7.2500     1  0  1
# 1          2.0       1.0     1.0  38.0    1.0    0.0  71.2833     0  0  0
# 2          3.0       1.0     3.0  26.0    0.0    0.0   7.9250     0  0  1
# 3          4.0       1.0     1.0  35.0    1.0    0.0  53.1000     0  0  1
# 4          5.0       0.0     3.0  35.0    0.0    0.0   8.0500     1  0  1

# %%
from sklearn.model_selection import train_test_split

# %%
train.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare',
#        'male', 'Q', 'S'],
#       dtype='object')

# %%
X=train.drop("Survived",axis=1)
y=train["Survived"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
from sklearn.linear_model import LogisticRegression

# %%
log=LogisticRegression()

# %%
log.fit(X_train,y_train)
# Out:
# C:\Users\Asus\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
predictions=log.predict(X_test)

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(predictions,y_test))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.85      0.83      0.84       190
#          1.0       0.70      0.74      0.72       104
#
#     accuracy                           0.80       294
#    macro avg       0.78      0.78      0.78       294
# weighted avg       0.80      0.80      0.80       294
